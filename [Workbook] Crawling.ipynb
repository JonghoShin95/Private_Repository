# %%
def make_fs_df(firm_code) : 
    
    # URL for the financial statement. I changed the structure of the URL, specifically moving the firm code part to the end of the URL.
    fs_url = 'https://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&cID=&MenuYn=Y&ReportGB=&NewMenuID=103&stkGb=D&gicode=A'+firm_code
    
    # Send HTTP request to fetch the page content
    fs_page = requests.get(fs_url)
    
    # Use StringIO to wrap the HTML content and pass it to pd.read_html
    fs_tables = pd.read_html(StringIO(fs_page.text))
    
    # Bring the first financial statement in the website and alter index the first column
    temp_df = fs_tables[0]
    temp_df = temp_df.set_index('IFRS(연결)')
    
    # Change index name 
    temp_df = temp_df.rename_axis('IFRS(Consolidated)')
    
    # Drop 'same FY from previous year' and the ratio column
    temp_df = temp_df.drop(columns=['전년동기', '전년동기(%)'])
    
    # Drop unnessesary rows except Sales, Operating Income and Net income
    temp_df = temp_df.loc[['매출액', '영업이익', '당기순이익']]
    
    # Bring Statement of financial position from the web site and set index as 'IFRS(Consolidated)' 
    temp_df2 = fs_tables[2]
    temp_df2 = temp_df2.set_index('IFRS(연결)')
    
    # Chane index name from 'IFRS(연결)' to 'IFRS(Consolidated)'
    temp_df2 = temp_df2.rename_axis('IFRS(Consolidated)')
    
    # Drop unnessesary rows except Assets, Liabilities, and Owner's Equity
    temp_df2 = temp_df2.loc[['자산', '부채', '자본']]
    
    # Bring the first financial statement in the website and alter index the first column
    temp_df3 = fs_tables[4]
    temp_df3 = temp_df3.set_index('IFRS(연결)')
    
    # Change index name 
    temp_df3 = temp_df3.rename_axis('IFRS(Consolidated)')
    
    # Drop unnessesary rows except Sales, Operating Income and Net income
    temp_df3 = temp_df3.loc[['영업활동으로인한현금흐름']]
    
    # Consolidate all the tables above into one table
    fs_df = pd.concat([temp_df, temp_df2, temp_df3])

    # Replace index with new value
    fs_df.index = ['Sales', 'Operating Income', 'Net Income', 'Assets', 'Liabilities', 'Owners Equity', 'Cashflow from Operating Activities']

    return fs_df

# %%
def make_fr_df(firm_code) :
    
    # URL for the financial ratio
    fr_url = 'https://comp.fnguide.com/SVO2/ASP/SVD_FinanceRatio.asp?pGB=1&cID=&MenuYn=Y&ReportGB=&NewMenuID=104&stkGb=D&gicode=A'+firm_code
    
    # Send HTTP request to fetch the page content
    fr_page = requests.get(fr_url)
    
    # Use StringIO to wrap the HTML content and pass it to pd.read_html
    fr_tables = pd.read_html(StringIO(fr_page.text))
    
    # Extract the first table from the list of tables
    # The first table in the list is stored in temp_df
    temp_df = fr_tables[0]
    
    # Set the first column as the index of the dataframe
    # The first column is used as the index for better organization and lookup of the rows
    temp_df = temp_df.set_index(temp_df.columns[0])
    
    # Filter the rows of interest based on specific index values
    # Select the rows that correspond to the financial ratios we want to examine (liquidity ratio, debt ratio, etc.)
    temp_df = temp_df.loc[['유동비율계산에 참여한 계정 펼치기', '부채비율계산에 참여한 계정 펼치기', '영업이익률계산에 참여한 계정 펼치기', 'ROA계산에 참여한 계정 펼치기', 'ROIC계산에 참여한 계정 펼치기']]
    
    # Replace index with new value
    temp_df.index = ['Liquidity Ratio', 'Debt Ratio', 'Operatig Income(%)', 'ROA', 'ROIC']

    # Display results
    return temp_df

# %%
# Function for making market index data frame
def make_invest_df(firm_code) :
    
    # URL for market index
    invest_url = 'https://comp.fnguide.com/SVO2/ASP/SVD_Invest.asp?pGB=1&cID=&MenuYn=Y&ReportGB=&NewMenuID=105&stkGb=D&gicode=A'+firm_code
    
    # Send HTTP request to fetch the page content
    invest_page = requests.get(invest_url)
    
    # Use StringIO to wrap the HTML content and pass it to pd.read_html
    invest_tables = pd.read_html(StringIO(invest_page.text))
        
    # Extract the first table from the list of tables
    temp_df = invest_tables[1]
    
    # Set the first column as the index of the dataframe. 
    temp_df = temp_df.set_index(temp_df.columns[0])
    
    # Select the rows that correspond to the financial ratios we want to examine
    temp_df = temp_df.loc[['EPS계산에 참여한 계정 펼치기(원)', 'PER계산에 참여한 계정 펼치기', 'PBR계산에 참여한 계정 펼치기', 'PCR계산에 참여한 계정 펼치기', 'PSR계산에 참여한 계정 펼치기', '총현금흐름']]
    
    
    # Replace index with new value
    temp_df.index = ['EPS', 'PER', 'PBR', 'PCR', 'PSR', 'Total Cashflow']
    
    
    return temp_df

# %%
# Function for changing structure of data frame
def change_df(firm_code, data_frame) : 

    # Create a new DataFrame where the firm code will be the column header for each of the existing columns
    for num, col in enumerate(data_frame.columns) : 

        # Create a temporary DataFrame with the firm code as a column name
        temp_df = pd.DataFrame({firm_code : data_frame[col]})
        
        # Transpose the temporary DataFrame so the columns become rows
        temp_df = temp_df.T

        # Set the new multi-level column index: the first level is the column name from fs_df, the second level is the column name from temp_df
        temp_df.columns = [[col]*len(data_frame), temp_df.columns]

        # If it's the first column, initialize total_df
        if num == 0:
            total_df = temp_df

        else : 
            # Merge the temporary DataFrame with the existing total_df on the index
            total_df = pd.merge(total_df, temp_df, how = 'outer', left_index = True, right_index = True)

            
    return total_df

# %%
# Make integrated consolidated financial statements data frame
import requests
import pandas as pd
from io import StringIO

# List of firm codes
firmcode_list = ['A005380', 'A005930', 'A035420', 'A003550', 'A034730']

# Loop through each firm code and get the financial data
for num, code in enumerate(firmcode_list) :
    fs_df = make_fs_df(code)     # Get financial data for each firm
    fs_df_changed = change_df(code, fs_df)     # Change the structure of the data

    # If it's the first initialize total_fs with the first comopany's data
    if num == 0 :
        total_fs = fs_df_changed

    # Otherwise, concatenate the current company's data to total_fs
    else :
        total_fs = pd.concat([total_fs, fs_df_changed])


# Display the consolidated financial statements for all companies
total_fs
# Out:
#            2021/12                                                     \
#              Sales Operating Income Net Income     Assets Liabilities
# A005380  1176106.0          66789.0    56931.0  2339464.0   1513306.0
# A005930  2796048.0         516339.0   399075.0  4266212.0   1217212.0
# A035420    68176.0          13255.0   164776.0   336910.0     96636.0
# A003550    68590.0          24601.0    26840.0   256698.0     37296.0
# A034730   972037.0          48598.0    57059.0  1653684.0    998157.0
#
#                                                             2022/12  \
#         Owners Equity Cashflow from Operating Activities      Sales
# A005380      826158.0                           -11764.0  1421515.0
# A005930     3048999.0                           651054.0  3022314.0
# A035420      240274.0                            13799.0    82201.0
# A003550      219402.0                            10195.0    71860.0
# A034730      655527.0                            61127.0  1320794.0
#
#                                      ...     2023/12                \
#         Operating Income Net Income  ... Liabilities Owners Equity
# A005380          98249.0    79836.0  ...   1806539.0     1018094.0
# A005930         433766.0   556541.0  ...    922281.0     3636779.0
# A035420          13047.0     6732.0  ...    114998.0      242380.0
# A003550          19414.0    21158.0  ...     32366.0      270165.0
# A034730          81613.0    39662.0  ...   1290912.0      778791.0
#
#                                               2024/09                   \
#         Cashflow from Operating Activities      Sales Operating Income
# A005380                           -25188.0  1286075.0         114174.0
# A005930                           441374.0  2250826.0         262333.0
# A035420                            20022.0    78521.0          14372.0
# A003550                             8827.0    53920.0          12088.0
# A034730                           113539.0   944599.0          25525.0
#
#                                                          \
#         Net Income     Assets Liabilities Owners Equity
# A005380   107558.0  3060866.0   1945726.0     1115140.0
# A005930   266970.0  4913073.0   1050260.0     3862814.0
# A035420    14179.0   373018.0    111465.0      261552.0
# A003550    11017.0   306084.0     29953.0      276131.0
# A034730    23273.0  2094729.0   1277088.0      817641.0
#
#
#         Cashflow from Operating Activities
# A005380                           -17304.0
# A005930                           509604.0
# A035420                            17213.0
# A003550                            10416.0
# A034730                            69383.0
#
# [5 rows x 28 columns]

# %%
# Make integrated financial ratio data frame
import requests
import pandas as pd
from io import StringIO

# List of firm codes
firmcode_list = ['A005380', 'A005930', 'A035420', 'A003550', 'A034730']

# Loop through each firm code and get the financial data
for num, code in enumerate(firmcode_list) :
    fr_df = make_fr_df(code)     # Get financial data for each firm
    fr_df_changed = change_df(code, fr_df)     # Change the structure of the data

    # If it's the first initialize total_fs with the first comopany's data
    if num == 0 :
        total_fr = fr_df_changed

    # Otherwise, concatenate the current company's data to total_fs
    else :
        total_fr = pd.concat([total_fr, fr_df_changed])


# Display the consolidated financial statements for all companies
total_fr
# Out:
#                 2020/12                                             \
#         Liquidity Ratio Debt Ratio Operatig Income(%)   ROA   ROIC
# A005380            85.9      174.2                2.3   1.0    1.9
# A005930           262.2       37.1               15.2   7.2   17.2
# A035420           133.3      106.1               22.9   5.8  171.0
# A003550           276.4       16.4               30.5   6.6   80.6
# A034730           102.3      165.5               -0.1  -0.1    0.9
#
#                 2021/12                                             ...  \
#         Liquidity Ratio Debt Ratio Operatig Income(%)   ROA   ROIC  ...
# A005380            83.0      183.2                5.7   2.6    3.8  ...
# A005930           247.6       39.9               18.5   9.9   23.9  ...
# A035420           140.9       40.2               19.4  65.0    NaN  ...
# A003550           196.8       17.0               35.9  10.8  157.0  ...
# A034730           109.4      152.3                5.0   3.8    6.4  ...
#
#                 2023/12                                            \
#         Liquidity Ratio Debt Ratio Operatig Income(%)   ROA  ROIC
# A005380            79.9      177.4                9.3   4.6   7.3
# A005930           258.8       25.4                2.5   3.4   3.8
# A035420           111.5       47.5               15.4   2.8  48.6
# A003550           268.4       12.0               21.3   4.7  99.2
# A034730            99.2      165.8                3.4  -0.2   9.2
#
#                 2024/09
#         Liquidity Ratio Debt Ratio Operatig Income(%)  ROA   ROIC
# A005380            83.5      174.5                8.9  4.9    6.5
# A005930           251.9       27.2               11.7  7.5   11.7
# A035420           159.5       42.6               18.3  5.2   53.8
# A003550           271.8       10.9               22.4  4.8  102.3
# A034730            94.6      156.2                2.7  1.5    2.6
#
# [5 rows x 25 columns]

# %%
# Make integrated market index data frame
import requests
import pandas as pd
from io import StringIO

# List of firm codes
firmcode_list = ['A005380', 'A005930', 'A035420', 'A003550', 'A034730']

# Loop through each firm code and get the financial data
for num, code in enumerate(firmcode_list) :
    invest_df = make_invest_df(code)     # Get financial data for each firm
    invest_df_changed = change_df(code, invest_df)     # Change the structure of the data

    # If it's the first initialize total_fs with the first comopany's data
    if num == 0 :
        total_invest = invest_df_changed

    # Otherwise, concatenate the current company's data to total_fs
    else :
        total_invest = pd.concat([total_invest, invest_df_changed])


# Display the consolidated financial statements for all companies
total_invest
# Out:
#         2020/12                                          2021/12               \
#             EPS    PER   PBR    PCR   PSR Total Cashflow     EPS    PER   PBR
# A005380    5144  37.33  0.75   9.48  0.51          63870   17846  11.71  0.75
# A005930    3841  21.09  2.06   9.75  2.32         564882    5777  13.55  1.80
# A035420    6097  47.97  5.60  32.10  9.06          13442  100400   3.77  2.52
# A003550    8334   9.92  0.72   8.87  2.80          14661   15499   5.22  0.61
# A034730    2670  90.08  0.89   2.09  0.21          85535   27592   9.10  0.81
#
#                ... 2023/12                             2024/09             \
#           PCR  ...     PBR    PCR   PSR Total Cashflow     EPS  PER   PBR
# A005380  6.09  ...    0.60   3.30  0.34         161011   37630  NaN  0.65
# A005930  7.24  ...    1.51  10.03  2.06         479071    3834  NaN  1.11
# A035420  3.67  ...    1.51  23.01  3.79          15723    8448  NaN  1.07
# A003550  4.89  ...    0.52   9.50  1.85          15765    6028  NaN  0.47
# A034730  1.73  ...    0.58   1.60  0.10         174800   11567  NaN  0.48
#
#
#          PCR  PSR Total Cashflow
# A005380  NaN  NaN         122154
# A005930  NaN  NaN         547727
# A035420  NaN  NaN          11444
# A003550  NaN  NaN          12017
# A034730  NaN  NaN          85945
#
# [5 rows x 30 columns]

# %%
import pandas as pd

# Load excel workbook for getting company codes listed in Korea market
path = r'C:\\Users\\jongh\\Downloads\\Korea Market Data.xlsx' # Designating file path 

# Read excel file
code_data = pd.read_excel(path)

# Drop the unnessesary columns
code_data = code_data[['영문 종목명', '단축코드']]

# Add a new column with the value 'A' + Code
code_data['Code'] = 'A' + code_data['단축코드']

# Set the company code as index
code_data = code_data.set_index(code_data.columns[2])

# Change column name to Company
code_data = code_data.rename(columns = {'영문 종목명' : 'Company'})

# Drop old company code
code_data = code_data.drop(columns = ['단축코드'])


# Reset index to make 'Code' column available again
code_data_reset = code_data.reset_index()

# Display results
code_data_reset
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[26], line 13
#      10 code_data = code_data[['영문 종목명', '단축코드']]
#      12 # Add a new column with the value 'A' + Code
# ---> 13 code_data['Code'] = 'A' + code_data['단축코드']
#      15 # Set the company code as index
#      16 code_data = code_data.set_index(code_data.columns[2])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:190, in OpsMixin.__radd__(self, other)
#     188 @unpack_zerodim_and_defer("__radd__")
#     189 def __radd__(self, other):
# --> 190     return self._arith_method(other, roperator.radd)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# File ~\anaconda3\Lib\site-packages\pandas\core\roperator.py:11, in radd(left, right)
#      10 def radd(left, right):
# ---> 11     return right + left
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U1'), dtype('int64')) -> None

# %%
import time # time used for pausing between requests to avoid overwhelming the server or triggering rate-limiting
import requests # requests used for sending HTTP requests to fetch the financial data from an external source (e.g., a website)

# List to store data frames that will be gathered and processed during the loop
dfs = []  # it initializes an empty list to store the individual data frames for each company code. These data frames will later be combined into a single data frame.

# Loop through each company code in the 'Code' column of the 'code_data_reset' DataFrame
for num, code in enumerate(code_data_reset['Code']):  # The loop iterates over the code column in the code_data_reset Dataframe. For each company, it fetches and processes the financial data.
    
    try:
        # Print progress to show the current company code being processed      
        print(f"Processing {num + 1}/{len(code_data_reset['Code'])} - Code: {code}") # It prints the progress of the cript, indicating which company code is being processed and what the progress is.

        # Sleep for 0.1 seconds to avoid making too many requests in a short time (helps prevent throttling or blocking)
        time.sleep(0.1) # This line adds a small delay of 0.1 seconds between requests to avoid making too many requests in a shor time, which could lead to rate-limiting or IP blocking from the server.

        try:
            # Attempt to fetch the financial data for the current company code
            fs_df = make_fs_df(code)  # This part of the codes attempts to fetch the financial data for the current company code using a function make_fs_df().
            

        except requests.exceptions.Timeout:  
        
            # Handle timeout error: if the request times out, wait 60 seconds and then retry fetching the data           
            print(f"Timeout occurred for code {code}. Retrying...")
            
            time.sleep(60)  # Wait for 60 seconds before retrying
            fs_df = make_fs_df(code) # If the request times out, the code waits for 60 seconds and tries again to fetch the data.

        except requests.exceptions.RequestException as e:

            # If there’s a request exception (e.g., network issues, bad response), log the error and move to the next code
            print(f"Request exception occurred for {code}: {e}") # If there's any other issue with the request (e.g., network issue, bad response), the exception is caught, an error message is printed, and the loop moves to the next company code.
            
            continue  # Skip the current iteration and continue with the next company code

        # Check if financial data is returned (fs_df is not None)      
        if fs_df is not None:
            
            # Process the data by changing its structure according to the logic in the 'change_df' function
            fs_df_changed = change_df(code, fs_df)
            
            # Append the processed data frame to the list 'dfs'
            dfs.append(fs_df_changed)

        else:

            # If no financial data is returned for the code, print a message indicating it's skipped           
            print(f"No data returned for {code}, skipping.")

    except (ValueError, KeyError) as e:

        # If there’s an error in processing the data for the code, catch the exception and continue to the next iteration
        print(f"Error processing code {code}: {e}")
        continue # Skip the current code and proceed to the next iteration

# After all iterations, if there are any data frames in the 'dfs' list, concatenate them
if dfs:
    
    # Concatenate all the data frames into one large data frame 'total_fs', row-wise (axis=0)
    total_fs = pd.concat(dfs, axis=0, ignore_index=True)
    print("Successfully consolidated financial data.")

else:
    # If no data frames were added to 'dfs', print a message indicating that no data was available
    print("No financial data available.")

# Display the consolidated financial data in 'total_fs'
total_fs
# Out:
# Processing 1/2865 - Code: A098120
# Processing 2/2865 - Code: A009520
# Error processing code A009520: "None of ['IFRS(연결)'] are in the columns"
# Processing 3/2865 - Code: A095570
# Processing 4/2865 - Code: A006840
# Processing 5/2865 - Code: A282330
# Processing 6/2865 - Code: A027410
# Processing 7/2865 - Code: A138930
# Error processing code A138930: "['매출액'] not in index"
# Processing 8/2865 - Code: A001465
# Error processing code A001465: No tables found
# Processing 9/2865 - Code: A001460
# Processing 10/2865 - Code: A001045
# Error processing code A001045: No tables found
# Processing 11/2865 - Code: A00104K
# Error processing code A00104K: No tables found
# Processing 12/2865 - Code: A001040
# Processing 13/2865 - Code: A011155
# Error processing code A011155: No tables found
# Processing 14/2865 - Code: A011150
# Processing 15/2865 - Code: A058820
# Processing 16/2865 - Code: A000590
# Processing 17/2865 - Code: A012030
# Processing 18/2865 - Code: A016610
# Error processing code A016610: "['매출액'] not in index"
# Processing 19/2865 - Code: A005830
# Error processing code A005830: "['매출액'] not in index"
# Processing 20/2865 - Code: A000990
# Processing 21/2865 - Code: A139130
# Error processing code A139130: "['매출액'] not in index"
# Processing 22/2865 - Code: A001530
# Processing 23/2865 - Code: A000215
# Error processing code A000215: No tables found
# Processing 24/2865 - Code: A000210
# Processing 25/2865 - Code: A37550K
# Error processing code A37550K: No tables found
# Processing 26/2865 - Code: A37550L
# Error processing code A37550L: No tables found
# Processing 27/2865 - Code: A375500
# Processing 28/2865 - Code: A155660
# Processing 29/2865 - Code: A069730
# Error processing code A069730: "None of ['IFRS(연결)'] are in the columns"
# Processing 30/2865 - Code: A017860
# Processing 31/2865 - Code: A017940
# Processing 32/2865 - Code: A365550
# Processing 33/2865 - Code: A050120
# Processing 34/2865 - Code: A383220
# Processing 35/2865 - Code: A007700
# Processing 36/2865 - Code: A078935
# Error processing code A078935: No tables found
# Processing 37/2865 - Code: A006360
# Processing 38/2865 - Code: A078930
# Processing 39/2865 - Code: A012630
# Processing 40/2865 - Code: A294870
# Processing 41/2865 - Code: A097230
# Processing 42/2865 - Code: A014790
# Processing 43/2865 - Code: A024850
# Error processing code A024850: "None of ['IFRS(연결)'] are in the columns"
# Processing 44/2865 - Code: A204320
# Processing 45/2865 - Code: A060980
# Processing 46/2865 - Code: A035000
# Processing 47/2865 - Code: A003560
# Processing 48/2865 - Code: A175330
# Error processing code A175330: "['매출액'] not in index"
# Processing 49/2865 - Code: A234080
# Processing 50/2865 - Code: A001065
# Error processing code A001065: No tables found
# Processing 51/2865 - Code: A001067
# Error processing code A001067: No tables found
# Processing 52/2865 - Code: A001060
# Processing 53/2865 - Code: A096760
# Processing 54/2865 - Code: A105560
# Error processing code A105560: "['매출액'] not in index"
# Processing 55/2865 - Code: A432320
# Error processing code A432320: "None of ['IFRS(연결)'] are in the columns"
# Processing 56/2865 - Code: A024120
# Processing 57/2865 - Code: A009070
# Processing 58/2865 - Code: A044180
# Processing 59/2865 - Code: A003620
# Processing 60/2865 - Code: A016380
# Processing 61/2865 - Code: A001390
# Processing 62/2865 - Code: A033180
# Processing 63/2865 - Code: A001940
# Processing 64/2865 - Code: A025000
# Processing 65/2865 - Code: A092230
# Processing 66/2865 - Code: A000040
# Processing 67/2865 - Code: A093050
# Processing 68/2865 - Code: A003555
# Error processing code A003555: No tables found
# Processing 69/2865 - Code: A034220
# Processing 70/2865 - Code: A003550
# Processing 71/2865 - Code: A051905
# Error processing code A051905: No tables found
# Processing 72/2865 - Code: A051900
# Processing 73/2865 - Code: A373220
# Processing 74/2865 - Code: A032640
# Processing 75/2865 - Code: A011070
# Processing 76/2865 - Code: A066575
# Error processing code A066575: No tables found
# Processing 77/2865 - Code: A066570
# Processing 78/2865 - Code: A051915
# Error processing code A051915: No tables found
# Processing 79/2865 - Code: A051910
# Processing 80/2865 - Code: A079550
# Processing 81/2865 - Code: A010120
# Processing 82/2865 - Code: A000680
# Processing 83/2865 - Code: A006260
# Processing 84/2865 - Code: A229640
# Processing 85/2865 - Code: A108320
# Processing 86/2865 - Code: A001120
# Processing 87/2865 - Code: A086960
# Processing 88/2865 - Code: A023150
# Processing 89/2865 - Code: A035420
# Processing 90/2865 - Code: A181710
# Processing 91/2865 - Code: A338100
# Error processing code A338100: "None of ['IFRS(연결)'] are in the columns"
# Processing 92/2865 - Code: A034310
# Processing 93/2865 - Code: A008260
# Error processing code A008260: "None of ['IFRS(연결)'] are in the columns"
# Processing 94/2865 - Code: A004255
# Error processing code A004255: No tables found
# Processing 95/2865 - Code: A004250
# Processing 96/2865 - Code: A456040
# Processing 97/2865 - Code: A010955
# Error processing code A010955: No tables found
# Processing 98/2865 - Code: A010950
# Processing 99/2865 - Code: A950110
# Processing 100/2865 - Code: A005090
# Processing 101/2865 - Code: A001380
# Processing 102/2865 - Code: A001770
# Error processing code A001770: "None of ['IFRS(연결)'] are in the columns"
# Processing 103/2865 - Code: A002360
# Processing 104/2865 - Code: A009160
# Processing 105/2865 - Code: A123700
# Processing 106/2865 - Code: A025530
# Processing 107/2865 - Code: A03473K
# Error processing code A03473K: No tables found
# Processing 108/2865 - Code: A011790
# Processing 109/2865 - Code: A018670
# Processing 110/2865 - Code: A001740
# Processing 111/2865 - Code: A210980
# Processing 112/2865 - Code: A395400
# Error processing code A395400: "None of ['IFRS(연결)'] are in the columns"
# Processing 113/2865 - Code: A034730
# Processing 114/2865 - Code: A402340
# Processing 115/2865 - Code: A260870
# Error processing code A260870: "None of ['IFRS(연결)'] are in the columns"
# Processing 116/2865 - Code: A361610
# Processing 117/2865 - Code: A100090
# Processing 118/2865 - Code: A096775
# Error processing code A096775: No tables found
# Processing 119/2865 - Code: A096770
# Processing 120/2865 - Code: A001515
# Error processing code A001515: No tables found
# Processing 121/2865 - Code: A001510
# Error processing code A001510: "['매출액'] not in index"
# Processing 122/2865 - Code: A28513K
# Error processing code A28513K: No tables found
# Processing 123/2865 - Code: A285130
# Processing 124/2865 - Code: A017670
# Processing 125/2865 - Code: A003570
# Processing 126/2865 - Code: A064960
# Processing 127/2865 - Code: A100840
# Processing 128/2865 - Code: A036530
# Processing 129/2865 - Code: A005610
# Processing 130/2865 - Code: A465770
# Processing 131/2865 - Code: A011810
# Processing 132/2865 - Code: A077970
# Processing 133/2865 - Code: A084870
# Processing 134/2865 - Code: A002710
# Processing 135/2865 - Code: A024070
# Processing 136/2865 - Code: A079940
# Processing 137/2865 - Code: A078890
# Processing 138/2865 - Code: A000500
# Processing 139/2865 - Code: A399720
# Processing 140/2865 - Code: A296520
# Processing 141/2865 - Code: A036620
# Error processing code A036620: "None of ['IFRS(연결)'] are in the columns"
# Processing 142/2865 - Code: A000860
# Processing 143/2865 - Code: A198440
# Error processing code A198440: "None of ['IFRS(연결)'] are in the columns"
# Processing 144/2865 - Code: A217730
# Processing 145/2865 - Code: A035250
# Processing 146/2865 - Code: A114190
# Processing 147/2865 - Code: A094480
# Processing 148/2865 - Code: A011420
# Error processing code A011420: "None of ['IFRS(연결)'] are in the columns"
# Processing 149/2865 - Code: A039240
# Error processing code A039240: "None of ['IFRS(연결)'] are in the columns"
# Processing 150/2865 - Code: A053950
# Processing 151/2865 - Code: A002100
# Processing 152/2865 - Code: A009450
# Processing 153/2865 - Code: A267290
# Processing 154/2865 - Code: A012320
# Processing 155/2865 - Code: A011040
# Processing 156/2865 - Code: A000050
# Processing 157/2865 - Code: A214390
# Error processing code A214390: "None of ['IFRS(연결)'] are in the columns"
# Processing 158/2865 - Code: A012610
# Processing 159/2865 - Code: A009140
# Processing 160/2865 - Code: A024910
# Processing 161/2865 - Code: A013580
# Processing 162/2865 - Code: A012205
# Error processing code A012205: No tables found
# Processing 163/2865 - Code: A012200
# Processing 164/2865 - Code: A002140
# Processing 165/2865 - Code: A049720
# Processing 166/2865 - Code: A010130
# Processing 167/2865 - Code: A002240
# Processing 168/2865 - Code: A014570
# Error processing code A014570: "None of ['IFRS(연결)'] are in the columns"
# Processing 169/2865 - Code: A348150
# Processing 170/2865 - Code: A950190
# Processing 171/2865 - Code: A098460
# Processing 172/2865 - Code: A035290
# Error processing code A035290: "None of ['IFRS(연결)'] are in the columns"
# Processing 173/2865 - Code: A215000
# Processing 174/2865 - Code: A121440
# Processing 175/2865 - Code: A366030
# Processing 176/2865 - Code: A076340
# Error processing code A076340: "None of ['IFRS(연결)'] are in the columns"
# Processing 177/2865 - Code: A009290
# Processing 178/2865 - Code: A086220
# Error processing code A086220: "None of ['IFRS(연결)'] are in the columns"
# Processing 179/2865 - Code: A014200
# Error processing code A014200: "None of ['IFRS(연결)'] are in the columns"
# Processing 180/2865 - Code: A017040
# Error processing code A017040: "None of ['IFRS(연결)'] are in the columns"
# Processing 181/2865 - Code: A029480
# Processing 182/2865 - Code: A017900
# Processing 183/2865 - Code: A037710
# Error processing code A037710: "None of ['IFRS(연결)'] are in the columns"
# Processing 184/2865 - Code: A026910
# Processing 185/2865 - Code: A440790
# Error processing code A440790: "None of ['IFRS(연결)'] are in the columns"
# Processing 186/2865 - Code: A456490
# Error processing code A456490: "None of ['IFRS(연결)'] are in the columns"
# Processing 187/2865 - Code: A465320
# Error processing code A465320: "None of ['IFRS(연결)'] are in the columns"
# Processing 188/2865 - Code: A482520
# Error processing code A482520: "None of ['IFRS(연결)'] are in the columns"
# Processing 189/2865 - Code: A489210
# Error processing code A489210: "None of ['IFRS(연결)'] are in the columns"
# Processing 190/2865 - Code: A030610
# Error processing code A030610: "['매출액'] not in index"
# Processing 191/2865 - Code: A339770
# Processing 192/2865 - Code: A053270
# Processing 193/2865 - Code: A007690
# Processing 194/2865 - Code: A066620
# Processing 195/2865 - Code: A001140
# Processing 196/2865 - Code: A043650
# Processing 197/2865 - Code: A006050
# Error processing code A006050: "None of ['IFRS(연결)'] are in the columns"
# Processing 198/2865 - Code: A060480
# Error processing code A060480: "None of ['IFRS(연결)'] are in the columns"
# Processing 199/2865 - Code: A078130
# Processing 200/2865 - Code: A307750
# Processing 201/2865 - Code: A002720
# Processing 202/2865 - Code: A243870
# Error processing code A243870: "None of ['IFRS(연결)'] are in the columns"
# Processing 203/2865 - Code: A035080
# Processing 204/2865 - Code: A114090
# Processing 205/2865 - Code: A900290
# Processing 206/2865 - Code: A453450
# Processing 207/2865 - Code: A204020
# Processing 208/2865 - Code: A402490
# Processing 209/2865 - Code: A114450
# Error processing code A114450: "None of ['IFRS(연결)'] are in the columns"
# Processing 210/2865 - Code: A083420
# Error processing code A083420: "None of ['IFRS(연결)'] are in the columns"
# Processing 211/2865 - Code: A186230
# Processing 212/2865 - Code: A014530
# Processing 213/2865 - Code: A083450
# Processing 214/2865 - Code: A900070
# Processing 215/2865 - Code: A204620
# Processing 216/2865 - Code: A019660
# Error processing code A019660: "None of ['IFRS(연결)'] are in the columns"
# Processing 217/2865 - Code: A014285
# Error processing code A014285: No tables found
# Processing 218/2865 - Code: A014280
# Processing 219/2865 - Code: A053260
# Processing 220/2865 - Code: A008870
# Processing 221/2865 - Code: A282720
# Processing 222/2865 - Code: A001570
# Processing 223/2865 - Code: A002995
# Error processing code A002995: No tables found
# Processing 224/2865 - Code: A002990
# Processing 225/2865 - Code: A011785
# Error processing code A011785: No tables found
# Processing 226/2865 - Code: A011780
# Processing 227/2865 - Code: A214330
# Processing 228/2865 - Code: A001210
# Processing 229/2865 - Code: A073240
# Processing 230/2865 - Code: A036190
# Processing 231/2865 - Code: A049080
# Processing 232/2865 - Code: A420770
# Error processing code A420770: "None of ['IFRS(연결)'] are in the columns"
# Processing 233/2865 - Code: A035460
# Processing 234/2865 - Code: A092440
# Processing 235/2865 - Code: A000270
# Processing 236/2865 - Code: A456700
# Error processing code A456700: "None of ['IFRS(연결)'] are in the columns"
# Processing 237/2865 - Code: A013700
# Processing 238/2865 - Code: A308100
# Processing 239/2865 - Code: A004545
# Error processing code A004545: No tables found
# Processing 240/2865 - Code: A004540
# Processing 241/2865 - Code: A407400
# Processing 242/2865 - Code: A187790
# Processing 243/2865 - Code: A286750
# Processing 244/2865 - Code: A121600
# Processing 245/2865 - Code: A247660
# Error processing code A247660: "None of ['IFRS(연결)'] are in the columns"
# Processing 246/2865 - Code: A039860
# Processing 247/2865 - Code: A091970
# Processing 248/2865 - Code: A417010
# Processing 249/2865 - Code: A244880
# Error processing code A244880: "None of ['IFRS(연결)'] are in the columns"
# Processing 250/2865 - Code: A405920
# Processing 251/2865 - Code: A288490
# Error processing code A288490: "None of ['IFRS(연결)'] are in the columns"
# Processing 252/2865 - Code: A051490
# Processing 253/2865 - Code: A137080
# Processing 254/2865 - Code: A190510
# Processing 255/2865 - Code: A242040
# Processing 256/2865 - Code: A089600
# Processing 257/2865 - Code: A293580
# Error processing code A293580: "['매출액'] not in index"
# Processing 258/2865 - Code: A257990
# Processing 259/2865 - Code: A138610
# Error processing code A138610: "None of ['IFRS(연결)'] are in the columns"
# Processing 260/2865 - Code: A130580
# Processing 261/2865 - Code: A036800
# Processing 262/2865 - Code: A030190
# Processing 263/2865 - Code: A267320
# Processing 264/2865 - Code: A001260
# Processing 265/2865 - Code: A008355
# Error processing code A008355: No tables found
# Processing 266/2865 - Code: A008350
# Processing 267/2865 - Code: A004270
# Processing 268/2865 - Code: A003925
# Error processing code A003925: No tables found
# Processing 269/2865 - Code: A003920
# Processing 270/2865 - Code: A025860
# Processing 271/2865 - Code: A111710
# Error processing code A111710: "None of ['IFRS(연결)'] are in the columns"
# Processing 272/2865 - Code: A091590
# Processing 273/2865 - Code: A168330
# Processing 274/2865 - Code: A094860
# Processing 275/2865 - Code: A253590
# Processing 276/2865 - Code: A212560
# Error processing code A212560: "None of ['IFRS(연결)'] are in the columns"
# Processing 277/2865 - Code: A095660
# Processing 278/2865 - Code: A042420
# Processing 279/2865 - Code: A950220
# Processing 280/2865 - Code: A311390
# Processing 281/2865 - Code: A085910
# Processing 282/2865 - Code: A092730
# Processing 283/2865 - Code: A290660
# Processing 284/2865 - Code: A306620
# Processing 285/2865 - Code: A153460
# Error processing code A153460: "None of ['IFRS(연결)'] are in the columns"
# Processing 286/2865 - Code: A007390
# Processing 287/2865 - Code: A033640
# Processing 288/2865 - Code: A330860
# Error processing code A330860: "None of ['IFRS(연결)'] are in the columns"
# Processing 289/2865 - Code: A005725
# Error processing code A005725: No tables found
# Processing 290/2865 - Code: A005720
# Processing 291/2865 - Code: A002355
# Error processing code A002355: No tables found
# Processing 292/2865 - Code: A002350
# Processing 293/2865 - Code: A089140
# Processing 294/2865 - Code: A389650
# Error processing code A389650: "None of ['IFRS(연결)'] are in the columns"
# Processing 295/2865 - Code: A137940
# Processing 296/2865 - Code: A160550
# Processing 297/2865 - Code: A396270
# Error processing code A396270: "None of ['IFRS(연결)'] are in the columns"
# Processing 298/2865 - Code: A348210
# Processing 299/2865 - Code: A092790
# Processing 300/2865 - Code: A225570
# Processing 301/2865 - Code: A217270
# Processing 302/2865 - Code: A251270
# Processing 303/2865 - Code: A317860
# Processing 304/2865 - Code: A104620
# Processing 305/2865 - Code: A090355
# Error processing code A090355: No tables found
# Processing 306/2865 - Code: A090350
# Processing 307/2865 - Code: A000325
# Error processing code A000325: No tables found
# Processing 308/2865 - Code: A000320
# Processing 309/2865 - Code: A473980
# Processing 310/2865 - Code: A194700
# Processing 311/2865 - Code: A285490
# Processing 312/2865 - Code: A283100
# Processing 313/2865 - Code: A145170
# Processing 314/2865 - Code: A229500
# Error processing code A229500: "None of ['IFRS(연결)'] are in the columns"
# Processing 315/2865 - Code: A106520
# Processing 316/2865 - Code: A376930
# Processing 317/2865 - Code: A006280
# Processing 318/2865 - Code: A142280
# Processing 319/2865 - Code: A234690
# Processing 320/2865 - Code: A005257
# Error processing code A005257: No tables found
# Processing 321/2865 - Code: A005250
# Processing 322/2865 - Code: A004370
# Processing 323/2865 - Code: A072710
# Processing 324/2865 - Code: A154030
# Processing 325/2865 - Code: A403490
# Processing 326/2865 - Code: A054050
# Processing 327/2865 - Code: A069140
# Processing 328/2865 - Code: A040160
# Processing 329/2865 - Code: A332290
# Processing 330/2865 - Code: A348340
# Processing 331/2865 - Code: A060260
# Processing 332/2865 - Code: A123840
# Processing 333/2865 - Code: A012340
# Processing 334/2865 - Code: A270870
# Processing 335/2865 - Code: A144960
# Processing 336/2865 - Code: A085670
# Processing 337/2865 - Code: A064260
# Processing 338/2865 - Code: A340360
# Error processing code A340360: "None of ['IFRS(연결)'] are in the columns"
# Processing 339/2865 - Code: A039560
# Processing 340/2865 - Code: A154040
# Error processing code A154040: "None of ['IFRS(연결)'] are in the columns"
# Processing 341/2865 - Code: A058730
# Processing 342/2865 - Code: A030210
# Error processing code A030210: "['매출액'] not in index"
# Processing 343/2865 - Code: A023590
# Processing 344/2865 - Code: A032190
# Processing 345/2865 - Code: A323350
# Error processing code A323350: "None of ['IFRS(연결)'] are in the columns"
# Processing 346/2865 - Code: A068240
# Processing 347/2865 - Code: A145210
# Processing 348/2865 - Code: A464580
# Processing 349/2865 - Code: A019680
# Processing 350/2865 - Code: A019685
# Error processing code A019685: No tables found
# Processing 351/2865 - Code: A006370
# Processing 352/2865 - Code: A00806K
# Error processing code A00806K: No tables found
# Processing 353/2865 - Code: A008060
# Processing 354/2865 - Code: A353200
# Processing 355/2865 - Code: A35320K
# Error processing code A35320K: No tables found
# Processing 356/2865 - Code: A178600
# Error processing code A178600: "None of ['IFRS(연결)'] are in the columns"
# Processing 357/2865 - Code: A020400
# Error processing code A020400: "None of ['IFRS(연결)'] are in the columns"
# Processing 358/2865 - Code: A008830
# Error processing code A008830: "None of ['IFRS(연결)'] are in the columns"
# Processing 359/2865 - Code: A000490
# Processing 360/2865 - Code: A048470
# Error processing code A048470: "None of ['IFRS(연결)'] are in the columns"
# Processing 361/2865 - Code: A008110
# Processing 362/2865 - Code: A004780
# Error processing code A004780: "None of ['IFRS(연결)'] are in the columns"
# Processing 363/2865 - Code: A005750
# Processing 364/2865 - Code: A017650
# Processing 365/2865 - Code: A006570
# Processing 366/2865 - Code: A007720
# Processing 367/2865 - Code: A389260
# Processing 368/2865 - Code: A317850
# Processing 369/2865 - Code: A290670
# Processing 370/2865 - Code: A078140
# Processing 371/2865 - Code: A065150
# Processing 372/2865 - Code: A001685
# Error processing code A001685: No tables found
# Processing 373/2865 - Code: A001680
# Processing 374/2865 - Code: A084695
# Error processing code A084695: No tables found
# Processing 375/2865 - Code: A084690
# Processing 376/2865 - Code: A036480
# Error processing code A036480: "None of ['IFRS(연결)'] are in the columns"
# Processing 377/2865 - Code: A128820
# Processing 378/2865 - Code: A117580
# Processing 379/2865 - Code: A027830
# Error processing code A027830: "None of ['IFRS(연결)'] are in the columns"
# Processing 380/2865 - Code: A104040
# Error processing code A104040: "None of ['IFRS(연결)'] are in the columns"
# Processing 381/2865 - Code: A129920
# Processing 382/2865 - Code: A016710
# Processing 383/2865 - Code: A442310
# Error processing code A442310: "None of ['IFRS(연결)'] are in the columns"
# Processing 384/2865 - Code: A457390
# Error processing code A457390: "None of ['IFRS(연결)'] are in the columns"
# Processing 385/2865 - Code: A457630
# Error processing code A457630: "None of ['IFRS(연결)'] are in the columns"
# Processing 386/2865 - Code: A471050
# Error processing code A471050: "None of ['IFRS(연결)'] are in the columns"
# Processing 387/2865 - Code: A478780
# Error processing code A478780: "None of ['IFRS(연결)'] are in the columns"
# Processing 388/2865 - Code: A482690
# Error processing code A482690: "None of ['IFRS(연결)'] are in the columns"
# Processing 389/2865 - Code: A020180
# Error processing code A020180: "None of ['IFRS(연결)'] are in the columns"
# Processing 390/2865 - Code: A003545
# Error processing code A003545: No tables found
# Processing 391/2865 - Code: A003547
# Error processing code A003547: No tables found
# Processing 392/2865 - Code: A003540
# Error processing code A003540: "['매출액'] not in index"
# Processing 393/2865 - Code: A045390
# Processing 394/2865 - Code: A009190
# Error processing code A009190: "None of ['IFRS(연결)'] are in the columns"
# Processing 395/2865 - Code: A108380
# Processing 396/2865 - Code: A014160
# Error processing code A014160: "None of ['IFRS(연결)'] are in the columns"
# Processing 397/2865 - Code: A047040
# Processing 398/2865 - Code: A003090
# Processing 399/2865 - Code: A069620
# Processing 400/2865 - Code: A007680
# Processing 401/2865 - Code: A000430
# Processing 402/2865 - Code: A048910
# Processing 403/2865 - Code: A005710
# Processing 404/2865 - Code: A006345
# Error processing code A006345: No tables found
# Processing 405/2865 - Code: A006340
# Processing 406/2865 - Code: A003220
# Processing 407/2865 - Code: A024890
# Processing 408/2865 - Code: A290380
# Error processing code A290380: "None of ['IFRS(연결)'] are in the columns"
# Processing 409/2865 - Code: A002880
# Processing 410/2865 - Code: A000300
# Processing 411/2865 - Code: A120240
# Error processing code A120240: "None of ['IFRS(연결)'] are in the columns"
# Processing 412/2865 - Code: A003310
# Processing 413/2865 - Code: A114920
# Error processing code A114920: "None of ['IFRS(연결)'] are in the columns"
# Processing 414/2865 - Code: A078600
# Processing 415/2865 - Code: A015230
# Processing 416/2865 - Code: A012800
# Processing 417/2865 - Code: A096350
# Processing 418/2865 - Code: A140520
# Processing 419/2865 - Code: A131220
# Processing 420/2865 - Code: A010170
# Processing 421/2865 - Code: A054670
# Error processing code A054670: "None of ['IFRS(연결)'] are in the columns"
# Processing 422/2865 - Code: A001070
# Processing 423/2865 - Code: A023910
# Error processing code A023910: "None of ['IFRS(연결)'] are in the columns"
# Processing 424/2865 - Code: A006650
# Processing 425/2865 - Code: A001440
# Processing 426/2865 - Code: A084010
# Processing 427/2865 - Code: A001795
# Error processing code A001795: No tables found
# Processing 428/2865 - Code: A001790
# Processing 429/2865 - Code: A001130
# Processing 430/2865 - Code: A003495
# Error processing code A003495: No tables found
# Processing 431/2865 - Code: A003490
# Processing 432/2865 - Code: A005880
# Processing 433/2865 - Code: A003830
# Error processing code A003830: "None of ['IFRS(연결)'] are in the columns"
# Processing 434/2865 - Code: A016090
# Error processing code A016090: "None of ['IFRS(연결)'] are in the columns"
# Processing 435/2865 - Code: A069460
# Error processing code A069460: "None of ['IFRS(연결)'] are in the columns"
# Processing 436/2865 - Code: A021040
# Processing 437/2865 - Code: A021045
# Error processing code A021045: No tables found
# Processing 438/2865 - Code: A067080
# Processing 439/2865 - Code: A043090
# Processing 440/2865 - Code: A298540
# Processing 441/2865 - Code: A032860
# Error processing code A032860: "None of ['IFRS(연결)'] are in the columns"
# Processing 442/2865 - Code: A475560
# Processing 443/2865 - Code: A192080
# Processing 444/2865 - Code: A393890
# Processing 445/2865 - Code: A299170
# Processing 446/2865 - Code: A089230
# Processing 447/2865 - Code: A012510
# Processing 448/2865 - Code: A224060
# Processing 449/2865 - Code: A302920
# Error processing code A302920: "None of ['IFRS(연결)'] are in the columns"
# Processing 450/2865 - Code: A213420
# Processing 451/2865 - Code: A317330
# Processing 452/2865 - Code: A077360
# Processing 453/2865 - Code: A004835
# Error processing code A004835: No tables found
# Processing 454/2865 - Code: A004830
# Processing 455/2865 - Code: A090410
# Processing 456/2865 - Code: A024900
# Processing 457/2865 - Code: A263600
# Processing 458/2865 - Code: A194480
# Processing 459/2865 - Code: A263800
# Error processing code A263800: "None of ['IFRS(연결)'] are in the columns"
# Processing 460/2865 - Code: A199150
# Processing 461/2865 - Code: A206560
# Processing 462/2865 - Code: A261200
# Processing 463/2865 - Code: A145720
# Processing 464/2865 - Code: A227420
# Error processing code A227420: "None of ['IFRS(연결)'] are in the columns"
# Processing 465/2865 - Code: A067990
# Processing 466/2865 - Code: A002150
# Processing 467/2865 - Code: A006620
# Processing 468/2865 - Code: A005160
# Processing 469/2865 - Code: A460850
# Error processing code A460850: "None of ['IFRS(연결)'] are in the columns"
# Processing 470/2865 - Code: A075970
# Processing 471/2865 - Code: A100130
# Processing 472/2865 - Code: A460860
# Error processing code A460860: "None of ['IFRS(연결)'] are in the columns"
# Processing 473/2865 - Code: A086450
# Processing 474/2865 - Code: A001230
# Processing 475/2865 - Code: A004140
# Processing 476/2865 - Code: A099410
# Error processing code A099410: "None of ['IFRS(연결)'] are in the columns"
# Processing 477/2865 - Code: A007590
# Processing 478/2865 - Code: A005965
# Error processing code A005965: No tables found
# Processing 479/2865 - Code: A005960
# Processing 480/2865 - Code: A026960
# Processing 481/2865 - Code: A002210
# Error processing code A002210: "None of ['IFRS(연결)'] are in the columns"
# Processing 482/2865 - Code: A102260
# Processing 483/2865 - Code: A033500
# Processing 484/2865 - Code: A025950
# Error processing code A025950: "None of ['IFRS(연결)'] are in the columns"
# Processing 485/2865 - Code: A000640
# Processing 486/2865 - Code: A170900
# Processing 487/2865 - Code: A088130
# Processing 488/2865 - Code: A028100
# Processing 489/2865 - Code: A041930
# Processing 490/2865 - Code: A001525
# Error processing code A001525: No tables found
# Processing 491/2865 - Code: A001527
# Error processing code A001527: No tables found
# Processing 492/2865 - Code: A084670
# Processing 493/2865 - Code: A001520
# Processing 494/2865 - Code: A082640
# Error processing code A082640: "['매출액'] not in index"
# Processing 495/2865 - Code: A060380
# Processing 496/2865 - Code: A079960
# Processing 497/2865 - Code: A008970
# Processing 498/2865 - Code: A228340
# Error processing code A228340: "None of ['IFRS(연결)'] are in the columns"
# Processing 499/2865 - Code: A092780
# Processing 500/2865 - Code: A088910
# Processing 501/2865 - Code: A094170
# Error processing code A094170: "None of ['IFRS(연결)'] are in the columns"
# Processing 502/2865 - Code: A049770
# Processing 503/2865 - Code: A013120
# Processing 504/2865 - Code: A018500
# Processing 505/2865 - Code: A006040
# Processing 506/2865 - Code: A030720
# Processing 507/2865 - Code: A014825
# Error processing code A014825: No tables found
# Processing 508/2865 - Code: A014820
# Processing 509/2865 - Code: A111380
# Processing 510/2865 - Code: A163560
# Processing 511/2865 - Code: A109860
# Processing 512/2865 - Code: A032960
# Processing 513/2865 - Code: A004890
# Processing 514/2865 - Code: A023790
# Error processing code A023790: "None of ['IFRS(연결)'] are in the columns"
# Processing 515/2865 - Code: A002690
# Error processing code A002690: "None of ['IFRS(연결)'] are in the columns"
# Processing 516/2865 - Code: A005290
# Processing 517/2865 - Code: A025900
# Processing 518/2865 - Code: A000020
# Processing 519/2865 - Code: A000155
# Error processing code A000155: No tables found
# Processing 520/2865 - Code: A000157
# Error processing code A000157: No tables found
# Processing 521/2865 - Code: A454910
# Processing 522/2865 - Code: A241560
# Processing 523/2865 - Code: A000150
# Processing 524/2865 - Code: A034020
# Processing 525/2865 - Code: A131970
# Processing 526/2865 - Code: A33626K
# Error processing code A33626K: No tables found
# Processing 527/2865 - Code: A33626L
# Error processing code A33626L: No tables found
# Processing 528/2865 - Code: A336260
# Processing 529/2865 - Code: A016740
# Processing 530/2865 - Code: A073190
# Error processing code A073190: "None of ['IFRS(연결)'] are in the columns"
# Processing 531/2865 - Code: A176750
# Processing 532/2865 - Code: A030350
# Processing 533/2865 - Code: A203650
# Processing 534/2865 - Code: A223250
# Processing 535/2865 - Code: A060570
# Processing 536/2865 - Code: A362990
# Processing 537/2865 - Code: A192650
# Processing 538/2865 - Code: A217620
# Error processing code A217620: "None of ['IFRS(연결)'] are in the columns"
# Processing 539/2865 - Code: A016670
# Processing 540/2865 - Code: A187870
# Processing 541/2865 - Code: A456440
# Error processing code A456440: "None of ['IFRS(연결)'] are in the columns"
# Processing 542/2865 - Code: A477760
# Error processing code A477760: "None of ['IFRS(연결)'] are in the columns"
# Processing 543/2865 - Code: A489730
# Error processing code A489730: "None of ['IFRS(연결)'] are in the columns"
# Processing 544/2865 - Code: A024090
# Error processing code A024090: "None of ['IFRS(연결)'] are in the columns"
# Processing 545/2865 - Code: A003160
# Processing 546/2865 - Code: A092200
# Processing 547/2865 - Code: A110990
# Processing 548/2865 - Code: A004840
# Processing 549/2865 - Code: A263690
# Processing 550/2865 - Code: A214680
# Processing 551/2865 - Code: A347850
# Processing 552/2865 - Code: A377190
# Processing 553/2865 - Code: A263720
# Processing 554/2865 - Code: A376300
# Processing 555/2865 - Code: A241520
# Error processing code A241520: "['매출액'] not in index"
# Processing 556/2865 - Code: A109740
# Processing 557/2865 - Code: A290120
# Processing 558/2865 - Code: A025440
# Processing 559/2865 - Code: A196490
# Processing 560/2865 - Code: A066900
# Processing 561/2865 - Code: A180400
# Processing 562/2865 - Code: A127120
# Processing 563/2865 - Code: A092070
# Error processing code A092070: "None of ['IFRS(연결)'] are in the columns"
# Processing 564/2865 - Code: A007340
# Processing 565/2865 - Code: A068790
# Processing 566/2865 - Code: A039840
# Processing 567/2865 - Code: A219550
# Error processing code A219550: "None of ['IFRS(연결)'] are in the columns"
# Processing 568/2865 - Code: A013570
# Processing 569/2865 - Code: A310870
# Processing 570/2865 - Code: A210540
# Processing 571/2865 - Code: A104460
# Processing 572/2865 - Code: A079810
# Processing 573/2865 - Code: A113810
# Processing 574/2865 - Code: A043360
# Error processing code A043360: "None of ['IFRS(연결)'] are in the columns"
# Processing 575/2865 - Code: A099520
# Processing 576/2865 - Code: A197140
# Processing 577/2865 - Code: A068930
# Processing 578/2865 - Code: A033130
# Processing 579/2865 - Code: A060900
# Processing 580/2865 - Code: A105740
# Processing 581/2865 - Code: A263020
# Processing 582/2865 - Code: A290550
# Processing 583/2865 - Code: A066670
# Processing 584/2865 - Code: A187220
# Processing 585/2865 - Code: A383930
# Error processing code A383930: "None of ['IFRS(연결)'] are in the columns"
# Processing 586/2865 - Code: A131180
# Processing 587/2865 - Code: A315640
# Error processing code A315640: "None of ['IFRS(연결)'] are in the columns"
# Processing 588/2865 - Code: A223310
# Processing 589/2865 - Code: A317120
# Processing 590/2865 - Code: A462510
# Error processing code A462510: "None of ['IFRS(연결)'] are in the columns"
# Processing 591/2865 - Code: A042510
# Processing 592/2865 - Code: A232680
# Error processing code A232680: "None of ['IFRS(연결)'] are in the columns"
# Processing 593/2865 - Code: A418420
# Error processing code A418420: "None of ['IFRS(연결)'] are in the columns"
# Processing 594/2865 - Code: A300120
# Processing 595/2865 - Code: A171120
# Processing 596/2865 - Code: A388790
# Error processing code A388790: "None of ['IFRS(연결)'] are in the columns"
# Processing 597/2865 - Code: A347700
# Processing 598/2865 - Code: A214260
# Processing 599/2865 - Code: A403360
# Error processing code A403360: "None of ['IFRS(연결)'] are in the columns"
# Processing 600/2865 - Code: A171010
# Processing 601/2865 - Code: A084650
# Processing 602/2865 - Code: A217500
# Processing 603/2865 - Code: A092590
# Error processing code A092590: "None of ['IFRS(연결)'] are in the columns"
# Processing 604/2865 - Code: A038390
# Processing 605/2865 - Code: A294140
# Error processing code A294140: "None of ['IFRS(연결)'] are in the columns"
# Processing 606/2865 - Code: A443250
# Processing 607/2865 - Code: A228670
# Processing 608/2865 - Code: A228850
# Processing 609/2865 - Code: A412350
# Processing 610/2865 - Code: A199550
# Processing 611/2865 - Code: A281740
# Processing 612/2865 - Code: A277810
# Processing 613/2865 - Code: A215100
# Processing 614/2865 - Code: A090360
# Processing 615/2865 - Code: A238500
# Error processing code A238500: "None of ['IFRS(연결)'] are in the columns"
# Processing 616/2865 - Code: A108490
# Processing 617/2865 - Code: A900260
# Processing 618/2865 - Code: A223220
# Error processing code A223220: "None of ['IFRS(연결)'] are in the columns"
# Processing 619/2865 - Code: A067730
# Error processing code A067730: "None of ['IFRS(연결)'] are in the columns"
# Processing 620/2865 - Code: A071280
# Processing 621/2865 - Code: A032350
# Processing 622/2865 - Code: A089860
# Processing 623/2865 - Code: A330590
# Error processing code A330590: "None of ['IFRS(연결)'] are in the columns"
# Processing 624/2865 - Code: A000400
# Error processing code A000400: "None of ['IFRS(연결)'] are in the columns"
# Processing 625/2865 - Code: A023530
# Processing 626/2865 - Code: A020150
# Processing 627/2865 - Code: A280360
# Processing 628/2865 - Code: A286940
# Processing 629/2865 - Code: A004000
# Processing 630/2865 - Code: A00499K
# Error processing code A00499K: No tables found
# Processing 631/2865 - Code: A004990
# Processing 632/2865 - Code: A005305
# Error processing code A005305: No tables found
# Processing 633/2865 - Code: A005300
# Processing 634/2865 - Code: A011170
# Processing 635/2865 - Code: A071840
# Error processing code A071840: "None of ['IFRS(연결)'] are in the columns"
# Processing 636/2865 - Code: A328130
# Processing 637/2865 - Code: A038060
# Processing 638/2865 - Code: A474170
# Error processing code A474170: "None of ['IFRS(연결)'] are in the columns"
# Processing 639/2865 - Code: A162120
# Processing 640/2865 - Code: A253610
# Error processing code A253610: "None of ['IFRS(연결)'] are in the columns"
# Processing 641/2865 - Code: A141080
# Processing 642/2865 - Code: A058470
# Error processing code A058470: "None of ['IFRS(연결)'] are in the columns"
# Processing 643/2865 - Code: A016100
# Processing 644/2865 - Code: A012700
# Processing 645/2865 - Code: A302550
# Processing 646/2865 - Code: A073570
# Error processing code A073570: "None of ['IFRS(연결)'] are in the columns"
# Processing 647/2865 - Code: A377450
# Error processing code A377450: "None of ['IFRS(연결)'] are in the columns"
# Processing 648/2865 - Code: A277070
# Error processing code A277070: "['매출액'] not in index"
# Processing 649/2865 - Code: A042500
# Processing 650/2865 - Code: A193250
# Processing 651/2865 - Code: A219420
# Processing 652/2865 - Code: A439090
# Processing 653/2865 - Code: A027740
# Processing 654/2865 - Code: A195500
# Error processing code A195500: "None of ['IFRS(연결)'] are in the columns"
# Processing 655/2865 - Code: A357430
# Error processing code A357430: "None of ['IFRS(연결)'] are in the columns"
# Processing 656/2865 - Code: A377480
# Processing 657/2865 - Code: A305090
# Error processing code A305090: "None of ['IFRS(연결)'] are in the columns"
# Processing 658/2865 - Code: A448780
# Error processing code A448780: "None of ['IFRS(연결)'] are in the columns"
# Processing 659/2865 - Code: A424980
# Error processing code A424980: "None of ['IFRS(연결)'] are in the columns"
# Processing 660/2865 - Code: A169330
# Processing 661/2865 - Code: A038290
# Processing 662/2865 - Code: A001080
# Error processing code A001080: "None of ['IFRS(연결)'] are in the columns"
# Processing 663/2865 - Code: A267980
# Processing 664/2865 - Code: A005990
# Processing 665/2865 - Code: A093520
# Processing 666/2865 - Code: A377030
# Processing 667/2865 - Code: A088980
# Error processing code A088980: No tables found
# Processing 668/2865 - Code: A179720
# Error processing code A179720: "None of ['IFRS(연결)'] are in the columns"
# Processing 669/2865 - Code: A100590
# Processing 670/2865 - Code: A067280
# Processing 671/2865 - Code: A072870
# Processing 672/2865 - Code: A215200
# Processing 673/2865 - Code: A133750
# Processing 674/2865 - Code: A446540
# Error processing code A446540: "None of ['IFRS(연결)'] are in the columns"
# Processing 675/2865 - Code: A235980
# Processing 676/2865 - Code: A200580
# Processing 677/2865 - Code: A041920
# Processing 678/2865 - Code: A233250
# Processing 679/2865 - Code: A014100
# Processing 680/2865 - Code: A236340
# Error processing code A236340: "None of ['IFRS(연결)'] are in the columns"
# Processing 681/2865 - Code: A054180
# Processing 682/2865 - Code: A086900
# Processing 683/2865 - Code: A078160
# Processing 684/2865 - Code: A138040
# Error processing code A138040: "['매출액'] not in index"
# Processing 685/2865 - Code: A408920
# Processing 686/2865 - Code: A021880
# Error processing code A021880: "['매출액'] not in index"
# Processing 687/2865 - Code: A140410
# Processing 688/2865 - Code: A241770
# Processing 689/2865 - Code: A090370
# Processing 690/2865 - Code: A059210
# Processing 691/2865 - Code: A118000
# Processing 692/2865 - Code: A058110
# Processing 693/2865 - Code: A017180
# Processing 694/2865 - Code: A009900
# Processing 695/2865 - Code: A012690
# Error processing code A012690: "None of ['IFRS(연결)'] are in the columns"
# Processing 696/2865 - Code: A005360
# Processing 697/2865 - Code: A070960
# Processing 698/2865 - Code: A434480
# Processing 699/2865 - Code: A080420
# Processing 700/2865 - Code: A417970
# Processing 701/2865 - Code: A080160
# Processing 702/2865 - Code: A087260
# Processing 703/2865 - Code: A101330
# Processing 704/2865 - Code: A012860
# Processing 705/2865 - Code: A363260
# Processing 706/2865 - Code: A348030
# Processing 707/2865 - Code: A250060
# Error processing code A250060: "None of ['IFRS(연결)'] are in the columns"
# Processing 708/2865 - Code: A288980
# Processing 709/2865 - Code: A142760
# Processing 710/2865 - Code: A033200
# Processing 711/2865 - Code: A333050
# Error processing code A333050: "None of ['IFRS(연결)'] are in the columns"
# Processing 712/2865 - Code: A009680
# Processing 713/2865 - Code: A118990
# Processing 714/2865 - Code: A006920
# Processing 715/2865 - Code: A038340
# Processing 716/2865 - Code: A001810
# Processing 717/2865 - Code: A009200
# Processing 718/2865 - Code: A009580
# Processing 719/2865 - Code: A322970
# Error processing code A322970: "None of ['IFRS(연결)'] are in the columns"
# Processing 720/2865 - Code: A033920
# Processing 721/2865 - Code: A008420
# Error processing code A008420: "None of ['IFRS(연결)'] are in the columns"
# Processing 722/2865 - Code: A279600
# Error processing code A279600: "None of ['IFRS(연결)'] are in the columns"
# Processing 723/2865 - Code: A095500
# Processing 724/2865 - Code: A254490
# Processing 725/2865 - Code: A025560
# Processing 726/2865 - Code: A218150
# Processing 727/2865 - Code: A007120
# Error processing code A007120: "None of ['IFRS(연결)'] are in the columns"
# Processing 728/2865 - Code: A396690
# Processing 729/2865 - Code: A442900
# Error processing code A442900: "None of ['IFRS(연결)'] are in the columns"
# Processing 730/2865 - Code: A357250
# Error processing code A357250: "None of ['IFRS(연결)'] are in the columns"
# Processing 731/2865 - Code: A094800
# Error processing code A094800: No tables found
# Processing 732/2865 - Code: A100790
# Error processing code A100790: "['매출액'] not in index"
# Processing 733/2865 - Code: A412930
# Error processing code A412930: "None of ['IFRS(연결)'] are in the columns"
# Processing 734/2865 - Code: A446190
# Error processing code A446190: "None of ['IFRS(연결)'] are in the columns"
# Processing 735/2865 - Code: A448830
# Error processing code A448830: "None of ['IFRS(연결)'] are in the columns"
# Processing 736/2865 - Code: A477380
# Error processing code A477380: "None of ['IFRS(연결)'] are in the columns"
# Processing 737/2865 - Code: A477470
# Error processing code A477470: "None of ['IFRS(연결)'] are in the columns"
# Processing 738/2865 - Code: A478440
# Error processing code A478440: "None of ['IFRS(연결)'] are in the columns"
# Processing 739/2865 - Code: A482680
# Error processing code A482680: "None of ['IFRS(연결)'] are in the columns"
# Processing 740/2865 - Code: A085620
# Error processing code A085620: "['매출액'] not in index"
# Processing 741/2865 - Code: A006805
# Error processing code A006805: No tables found
# Processing 742/2865 - Code: A00680K
# Error processing code A00680K: No tables found
# Processing 743/2865 - Code: A006800
# Error processing code A006800: "['매출액'] not in index"
# Processing 744/2865 - Code: A208890
# Processing 745/2865 - Code: A049950
# Processing 746/2865 - Code: A207760
# Processing 747/2865 - Code: A002840
# Processing 748/2865 - Code: A268280
# Processing 749/2865 - Code: A107590
# Processing 750/2865 - Code: A134380
# Error processing code A134380: "None of ['IFRS(연결)'] are in the columns"
# Processing 751/2865 - Code: A351020
# Error processing code A351020: "None of ['IFRS(연결)'] are in the columns"
# Processing 752/2865 - Code: A003650
# Error processing code A003650: "None of ['IFRS(연결)'] are in the columns"
# Processing 753/2865 - Code: A059090
# Processing 754/2865 - Code: A214610
# Processing 755/2865 - Code: A201490
# Processing 756/2865 - Code: A452200
# Error processing code A452200: "None of ['IFRS(연결)'] are in the columns"
# Processing 757/2865 - Code: A418470
# Error processing code A418470: "None of ['IFRS(연결)'] are in the columns"
# Processing 758/2865 - Code: A206640
# Processing 759/2865 - Code: A018700
# Processing 760/2865 - Code: A035620
# Processing 761/2865 - Code: A354390
# Error processing code A354390: "None of ['IFRS(연결)'] are in the columns"
# Processing 762/2865 - Code: A053030
# Processing 763/2865 - Code: A301300
# Processing 764/2865 - Code: A377740
# Processing 765/2865 - Code: A064550
# Processing 766/2865 - Code: A314930
# Error processing code A314930: "None of ['IFRS(연결)'] are in the columns"
# Processing 767/2865 - Code: A208710
# Processing 768/2865 - Code: A086820
# Error processing code A086820: "None of ['IFRS(연결)'] are in the columns"
# Processing 769/2865 - Code: A038460
# Processing 770/2865 - Code: A251120
# Error processing code A251120: "None of ['IFRS(연결)'] are in the columns"
# Processing 771/2865 - Code: A199730
# Error processing code A199730: "None of ['IFRS(연결)'] are in the columns"
# Processing 772/2865 - Code: A266470
# Error processing code A266470: "None of ['IFRS(연결)'] are in the columns"
# Processing 773/2865 - Code: A289170
# Error processing code A289170: "None of ['IFRS(연결)'] are in the columns"
# Processing 774/2865 - Code: A086040
# Processing 775/2865 - Code: A199290
# Error processing code A199290: "None of ['IFRS(연결)'] are in the columns"
# Processing 776/2865 - Code: A099430
# Processing 777/2865 - Code: A032980
# Processing 778/2865 - Code: A308080
# Processing 779/2865 - Code: A043150
# Processing 780/2865 - Code: A323990
# Processing 781/2865 - Code: A003610
# Processing 782/2865 - Code: A267790
# Processing 783/2865 - Code: A001340
# Processing 784/2865 - Code: A046310
# Processing 785/2865 - Code: A035150
# Processing 786/2865 - Code: A331520
# Processing 787/2865 - Code: A199480
# Processing 788/2865 - Code: A438700
# Processing 789/2865 - Code: A066410
# Processing 790/2865 - Code: A002410
# Processing 791/2865 - Code: A382900
# Processing 792/2865 - Code: A206400
# Processing 793/2865 - Code: A019010
# Processing 794/2865 - Code: A177350
# Processing 795/2865 - Code: A457600
# Processing 796/2865 - Code: A424760
# Error processing code A424760: "None of ['IFRS(연결)'] are in the columns"
# Processing 797/2865 - Code: A007210
# Processing 798/2865 - Code: A225530
# Processing 799/2865 - Code: A250000
# Processing 800/2865 - Code: A002760
# Error processing code A002760: "None of ['IFRS(연결)'] are in the columns"
# Processing 801/2865 - Code: A003850
# Processing 802/2865 - Code: A310210
# Processing 803/2865 - Code: A006910
# Error processing code A006910: "None of ['IFRS(연결)'] are in the columns"
# Processing 804/2865 - Code: A000890
# Processing 805/2865 - Code: A226340
# Processing 806/2865 - Code: A206950
# Error processing code A206950: "None of ['IFRS(연결)'] are in the columns"
# Processing 807/2865 - Code: A008470
# Processing 808/2865 - Code: A003000
# Processing 809/2865 - Code: A001275
# Error processing code A001275: No tables found
# Processing 810/2865 - Code: A001270
# Error processing code A001270: "['매출액'] not in index"
# Processing 811/2865 - Code: A026940
# Error processing code A026940: "None of ['IFRS(연결)'] are in the columns"
# Processing 812/2865 - Code: A014470
# Processing 813/2865 - Code: A011390
# Processing 814/2865 - Code: A005030
# Error processing code A005030: "None of ['IFRS(연결)'] are in the columns"
# Processing 815/2865 - Code: A338220
# Processing 816/2865 - Code: A100120
# Processing 817/2865 - Code: A406820
# Processing 818/2865 - Code: A337930
# Processing 819/2865 - Code: A099390
# Processing 820/2865 - Code: A064480
# Error processing code A064480: "None of ['IFRS(연결)'] are in the columns"
# Processing 821/2865 - Code: A288330
# Processing 822/2865 - Code: A365900
# Processing 823/2865 - Code: A089970
# Processing 824/2865 - Code: A251630
# Processing 825/2865 - Code: A018290
# Processing 826/2865 - Code: A439580
# Processing 827/2865 - Code: A033560
# Processing 828/2865 - Code: A191600
# Error processing code A191600: "None of ['IFRS(연결)'] are in the columns"
# Processing 829/2865 - Code: A369370
# Processing 830/2865 - Code: A126340
# Processing 831/2865 - Code: A121800
# Processing 832/2865 - Code: A082800
# Processing 833/2865 - Code: A318410
# Processing 834/2865 - Code: A002070
# Processing 835/2865 - Code: A100220
# Processing 836/2865 - Code: A419540
# Error processing code A419540: "None of ['IFRS(연결)'] are in the columns"
# Processing 837/2865 - Code: A146320
# Processing 838/2865 - Code: A200780
# Processing 839/2865 - Code: A413640
# Error processing code A413640: "None of ['IFRS(연결)'] are in the columns"
# Processing 840/2865 - Code: A141000
# Processing 841/2865 - Code: A090460
# Processing 842/2865 - Code: A083650
# Processing 843/2865 - Code: A139050
# Processing 844/2865 - Code: A445360
# Error processing code A445360: "None of ['IFRS(연결)'] are in the columns"
# Processing 845/2865 - Code: A473370
# Error processing code A473370: "None of ['IFRS(연결)'] are in the columns"
# Processing 846/2865 - Code: A065170
# Processing 847/2865 - Code: A086670
# Processing 848/2865 - Code: A335890
# Error processing code A335890: "None of ['IFRS(연결)'] are in the columns"
# Processing 849/2865 - Code: A230980
# Processing 850/2865 - Code: A126600
# Processing 851/2865 - Code: A082920
# Processing 852/2865 - Code: A054220
# Processing 853/2865 - Code: A042370
# Processing 854/2865 - Code: A050090
# Error processing code A050090: "None of ['IFRS(연결)'] are in the columns"
# Processing 855/2865 - Code: A148780
# Processing 856/2865 - Code: A307870
# Processing 857/2865 - Code: A357880
# Processing 858/2865 - Code: A032850
# Processing 859/2865 - Code: A238200
# Processing 860/2865 - Code: A093190
# Processing 861/2865 - Code: A065450
# Processing 862/2865 - Code: A210120
# Error processing code A210120: "None of ['IFRS(연결)'] are in the columns"
# Processing 863/2865 - Code: A044480
# Processing 864/2865 - Code: A005180
# Processing 865/2865 - Code: A069540
# Processing 866/2865 - Code: A072950
# Processing 867/2865 - Code: A266170
# Processing 868/2865 - Code: A451250
# Processing 869/2865 - Code: A143240
# Processing 870/2865 - Code: A466410
# Error processing code A466410: "None of ['IFRS(연결)'] are in the columns"
# Processing 871/2865 - Code: A003960
# Processing 872/2865 - Code: A008040
# Error processing code A008040: "None of ['IFRS(연결)'] are in the columns"
# Processing 873/2865 - Code: A007160
# Processing 874/2865 - Code: A014710
# Processing 875/2865 - Code: A006090
# Error processing code A006090: "None of ['IFRS(연결)'] are in the columns"
# Processing 876/2865 - Code: A452430
# Error processing code A452430: "None of ['IFRS(연결)'] are in the columns"
# Processing 877/2865 - Code: A419120
# Processing 878/2865 - Code: A062040
# Error processing code A062040: "None of ['IFRS(연결)'] are in the columns"
# ...
# Processing 2659/2865 - Code: A054040
# Processing 2660/2865 - Code: A161890
# Processing 2661/2865 - Code: A021650
# Processing 2662/2865 - Code: A161390
# Processing 2663/2865 - Code: A034830
# Error processing code A034830: "['매출액'] not in index"
# Processing 2664/2865 - Code: A152550
# Error processing code A152550: No tables found
# Processing 2665/2865 - Code: A168490
# Error processing code A168490: No tables found
# Processing 2666/2865 - Code: A071055
# Error processing code A071055: No tables found
# Processing 2667/2865 - Code: A071050
# Error processing code A071050: "['매출액'] not in index"
# Processing 2668/2865 - Code: A007280
# Error processing code A007280: "None of ['IFRS(연결)'] are in the columns"
# Processing 2669/2865 - Code: A032300
# Error processing code A032300: "None of ['IFRS(연결)'] are in the columns"
# Processing 2670/2865 - Code: A037230
# Error processing code A037230: "None of ['IFRS(연결)'] are in the columns"
# Processing 2671/2865 - Code: A448900
# Processing 2672/2865 - Code: A047810
# Processing 2673/2865 - Code: A123690
# Processing 2674/2865 - Code: A003350
# Error processing code A003350: "None of ['IFRS(연결)'] are in the columns"
# Processing 2675/2865 - Code: A030520
# Processing 2676/2865 - Code: A052600
# Error processing code A052600: "None of ['IFRS(연결)'] are in the columns"
# Processing 2677/2865 - Code: A011500
# Error processing code A011500: "None of ['IFRS(연결)'] are in the columns"
# Processing 2678/2865 - Code: A002390
# Processing 2679/2865 - Code: A256150
# Error processing code A256150: "None of ['IFRS(연결)'] are in the columns"
# Processing 2680/2865 - Code: A092460
# Processing 2681/2865 - Code: A053690
# Processing 2682/2865 - Code: A042700
# Processing 2683/2865 - Code: A008930
# Processing 2684/2865 - Code: A128940
# Processing 2685/2865 - Code: A452190
# Processing 2686/2865 - Code: A047080
# Processing 2687/2865 - Code: A009240
# Processing 2688/2865 - Code: A452280
# Error processing code A452280: "None of ['IFRS(연결)'] are in the columns"
# Processing 2689/2865 - Code: A020000
# Processing 2690/2865 - Code: A003680
# Error processing code A003680: "None of ['IFRS(연결)'] are in the columns"
# Processing 2691/2865 - Code: A066980
# Processing 2692/2865 - Code: A105630
# Processing 2693/2865 - Code: A069640
# Processing 2694/2865 - Code: A016450
# Processing 2695/2865 - Code: A010420
# Processing 2696/2865 - Code: A009180
# Processing 2697/2865 - Code: A114810
# Processing 2698/2865 - Code: A070590
# Processing 2699/2865 - Code: A213500
# Processing 2700/2865 - Code: A014680
# Processing 2701/2865 - Code: A004710
# Processing 2702/2865 - Code: A004150
# Processing 2703/2865 - Code: A025750
# Processing 2704/2865 - Code: A226440
# Processing 2705/2865 - Code: A042520
# Processing 2706/2865 - Code: A004960
# Processing 2707/2865 - Code: A011700
# Processing 2708/2865 - Code: A430690
# Processing 2709/2865 - Code: A078350
# Processing 2710/2865 - Code: A045100
# Processing 2711/2865 - Code: A001755
# Error processing code A001755: No tables found
# Processing 2712/2865 - Code: A001750
# Error processing code A001750: "None of ['IFRS(연결)'] are in the columns"
# Processing 2713/2865 - Code: A018880
# Processing 2714/2865 - Code: A009420
# Processing 2715/2865 - Code: A320000
# Error processing code A320000: "None of ['IFRS(연결)'] are in the columns"
# Processing 2716/2865 - Code: A214870
# Processing 2717/2865 - Code: A091440
# Processing 2718/2865 - Code: A014130
# Processing 2719/2865 - Code: A024740
# Processing 2720/2865 - Code: A005860
# Processing 2721/2865 - Code: A300720
# Processing 2722/2865 - Code: A002220
# Processing 2723/2865 - Code: A006390
# Error processing code A006390: "None of ['IFRS(연결)'] are in the columns"
# Processing 2724/2865 - Code: A003300
# Processing 2725/2865 - Code: A007770
# Processing 2726/2865 - Code: A051600
# Processing 2727/2865 - Code: A130660
# Processing 2728/2865 - Code: A198940
# Processing 2729/2865 - Code: A058450
# Processing 2730/2865 - Code: A107640
# Processing 2731/2865 - Code: A002320
# Processing 2732/2865 - Code: A003480
# Processing 2733/2865 - Code: A18064K
# Error processing code A18064K: No tables found
# Processing 2734/2865 - Code: A180640
# Processing 2735/2865 - Code: A005110
# Processing 2736/2865 - Code: A079170
# Error processing code A079170: "None of ['IFRS(연결)'] are in the columns"
# Processing 2737/2865 - Code: A009460
# Error processing code A009460: "None of ['IFRS(연결)'] are in the columns"
# Processing 2738/2865 - Code: A372910
# Processing 2739/2865 - Code: A054920
# Processing 2740/2865 - Code: A457370
# Error processing code A457370: "None of ['IFRS(연결)'] are in the columns"
# Processing 2741/2865 - Code: A002680
# Processing 2742/2865 - Code: A000885
# Error processing code A000885: No tables found
# Processing 2743/2865 - Code: A00088K
# Error processing code A00088K: No tables found
# Processing 2744/2865 - Code: A45226K
# Error processing code A45226K: No tables found
# Processing 2745/2865 - Code: A452260
# Processing 2746/2865 - Code: A451800
# Error processing code A451800: "None of ['IFRS(연결)'] are in the columns"
# Processing 2747/2865 - Code: A000880
# Processing 2748/2865 - Code: A088350
# Error processing code A088350: "['매출액'] not in index"
# Processing 2749/2865 - Code: A000370
# Error processing code A000370: "['매출액'] not in index"
# Processing 2750/2865 - Code: A009835
# Error processing code A009835: No tables found
# Processing 2751/2865 - Code: A009830
# Processing 2752/2865 - Code: A272210
# Processing 2753/2865 - Code: A012450
# Processing 2754/2865 - Code: A082740
# Error processing code A082740: "None of ['IFRS(연결)'] are in the columns"
# Processing 2755/2865 - Code: A042660
# Processing 2756/2865 - Code: A489790
# Processing 2757/2865 - Code: A003535
# Error processing code A003535: No tables found
# Processing 2758/2865 - Code: A003530
# Error processing code A003530: "['매출액'] not in index"
# Processing 2759/2865 - Code: A455310
# Error processing code A455310: "None of ['IFRS(연결)'] are in the columns"
# Processing 2760/2865 - Code: A195870
# Processing 2761/2865 - Code: A034810
# Processing 2762/2865 - Code: A03481K
# Error processing code A03481K: No tables found
# Processing 2763/2865 - Code: A059270
# Error processing code A059270: "None of ['IFRS(연결)'] are in the columns"
# Processing 2764/2865 - Code: A076610
# Processing 2765/2865 - Code: A101530
# Processing 2766/2865 - Code: A220180
# Processing 2767/2865 - Code: A143210
# Processing 2768/2865 - Code: A900270
# Processing 2769/2865 - Code: A214180
# Processing 2770/2865 - Code: A234340
# Processing 2771/2865 - Code: A084990
# Processing 2772/2865 - Code: A000725
# Error processing code A000725: No tables found
# Processing 2773/2865 - Code: A000720
# Processing 2774/2865 - Code: A170030
# Processing 2775/2865 - Code: A453340
# Processing 2776/2865 - Code: A086280
# Processing 2777/2865 - Code: A064350
# Processing 2778/2865 - Code: A079430
# Processing 2779/2865 - Code: A012330
# Processing 2780/2865 - Code: A319400
# Processing 2781/2865 - Code: A052260
# Processing 2782/2865 - Code: A048410
# Processing 2783/2865 - Code: A069960
# Processing 2784/2865 - Code: A004560
# Processing 2785/2865 - Code: A016790
# Error processing code A016790: "None of ['IFRS(연결)'] are in the columns"
# Processing 2786/2865 - Code: A004310
# Error processing code A004310: "None of ['IFRS(연결)'] are in the columns"
# Processing 2787/2865 - Code: A041440
# Processing 2788/2865 - Code: A187660
# Processing 2789/2865 - Code: A039010
# Error processing code A039010: "None of ['IFRS(연결)'] are in the columns"
# Processing 2790/2865 - Code: A017800
# Processing 2791/2865 - Code: A307950
# Processing 2792/2865 - Code: A011210
# Processing 2793/2865 - Code: A090850
# Processing 2794/2865 - Code: A005385
# Error processing code A005385: No tables found
# Processing 2795/2865 - Code: A005387
# Error processing code A005387: No tables found
# Processing 2796/2865 - Code: A005389
# Error processing code A005389: No tables found
# Processing 2797/2865 - Code: A005380
# Processing 2798/2865 - Code: A004020
# Processing 2799/2865 - Code: A005440
# Processing 2800/2865 - Code: A001500
# Error processing code A001500: "['매출액'] not in index"
# Processing 2801/2865 - Code: A011760
# Processing 2802/2865 - Code: A227840
# Processing 2803/2865 - Code: A126560
# Processing 2804/2865 - Code: A001450
# Error processing code A001450: "['매출액'] not in index"
# Processing 2805/2865 - Code: A057050
# Processing 2806/2865 - Code: A460930
# Processing 2807/2865 - Code: A092300
# Processing 2808/2865 - Code: A138360
# Error processing code A138360: "None of ['IFRS(연결)'] are in the columns"
# Processing 2809/2865 - Code: A011080
# Error processing code A011080: "None of ['IFRS(연결)'] are in the columns"
# Processing 2810/2865 - Code: A093240
# Processing 2811/2865 - Code: A003010
# Error processing code A003010: "None of ['IFRS(연결)'] are in the columns"
# Processing 2812/2865 - Code: A111110
# Processing 2813/2865 - Code: A008775
# Error processing code A008775: No tables found
# Processing 2814/2865 - Code: A008770
# Processing 2815/2865 - Code: A060560
# Processing 2816/2865 - Code: A064240
# Processing 2817/2865 - Code: A039610
# Processing 2818/2865 - Code: A378850
# Processing 2819/2865 - Code: A241590
# Processing 2820/2865 - Code: A006060
# Processing 2821/2865 - Code: A013520
# Processing 2822/2865 - Code: A010690
# Processing 2823/2865 - Code: A126640
# Error processing code A126640: "None of ['IFRS(연결)'] are in the columns"
# Processing 2824/2865 - Code: A133820
# Processing 2825/2865 - Code: A127980
# Processing 2826/2865 - Code: A061250
# Error processing code A061250: "None of ['IFRS(연결)'] are in the columns"
# Processing 2827/2865 - Code: A010660
# Error processing code A010660: "None of ['IFRS(연결)'] are in the columns"
# Processing 2828/2865 - Code: A000850
# Processing 2829/2865 - Code: A016580
# Processing 2830/2865 - Code: A032560
# Processing 2831/2865 - Code: A004800
# Processing 2832/2865 - Code: A094280
# Processing 2833/2865 - Code: A097870
# Processing 2834/2865 - Code: A298040
# Processing 2835/2865 - Code: A298020
# Processing 2836/2865 - Code: A298000
# Processing 2837/2865 - Code: A093370
# Processing 2838/2865 - Code: A081660
# Processing 2839/2865 - Code: A290270
# Processing 2840/2865 - Code: A005870
# Error processing code A005870: "None of ['IFRS(연결)'] are in the columns"
# Processing 2841/2865 - Code: A353190
# Processing 2842/2865 - Code: A192410
# Processing 2843/2865 - Code: A090710
# Processing 2844/2865 - Code: A078590
# Error processing code A078590: "None of ['IFRS(연결)'] are in the columns"
# Processing 2845/2865 - Code: A205470
# Processing 2846/2865 - Code: A115160
# Processing 2847/2865 - Code: A028080
# Processing 2848/2865 - Code: A175140
# Processing 2849/2865 - Code: A200670
# Error processing code A200670: "None of ['IFRS(연결)'] are in the columns"
# Processing 2850/2865 - Code: A079980
# Processing 2851/2865 - Code: A065510
# Processing 2852/2865 - Code: A215090
# Error processing code A215090: "None of ['IFRS(연결)'] are in the columns"
# Processing 2853/2865 - Code: A005010
# Processing 2854/2865 - Code: A263920
# Processing 2855/2865 - Code: A243070
# Processing 2856/2865 - Code: A084110
# Processing 2857/2865 - Code: A145020
# Processing 2858/2865 - Code: A024060
# Error processing code A024060: "None of ['IFRS(연결)'] are in the columns"
# Processing 2859/2865 - Code: A010240
# Processing 2860/2865 - Code: A189980
# Processing 2861/2865 - Code: A000545
# Error processing code A000545: No tables found
# Processing 2862/2865 - Code: A000540
# Error processing code A000540: "None of ['IFRS(연결)'] are in the columns"
# Processing 2863/2865 - Code: A003280
# Processing 2864/2865 - Code: A037440
# Processing 2865/2865 - Code: A238490
# Successfully consolidated financial data.
#       2021/12                                                                 \
#         Sales Operating Income Net Income   Assets Liabilities Owners Equity
# 0       614.0             79.0       76.0    516.0        97.0         419.0
# 1      9819.0            481.0      767.0  13550.0      9925.0        3625.0
# 2     31677.0          -1657.0    -1993.0  45487.0     33464.0       12024.0
# 3     67812.0           1994.0     1476.0  25964.0     17871.0        8093.0
# 4      1502.0            379.0      360.0  19816.0      2489.0       17328.0
# ...       ...              ...        ...      ...         ...           ...
# 2017   1418.0            138.0      119.0   1184.0       325.0         859.0
# 2018    715.0             67.0       63.0   1319.0       505.0         814.0
# 2019    817.0            -19.0      164.0   2473.0      1444.0        1029.0
# 2020   2121.0             83.0       62.0   1741.0      1113.0         628.0
# 2021    506.0            -44.0       -4.0    843.0       104.0         739.0
#
#                                          2022/12                              \
#      Cashflow from Operating Activities    Sales Operating Income Net Income
# 0                                  90.0    611.0             79.0       70.0
# 1                                -113.0  11937.0            764.0       87.0
# 2                                 -98.0  37880.0           -218.0    -1249.0
# 3                                5381.0  76158.0           2524.0     1935.0
# 4                                  15.0   4350.0            612.0      262.0
# ...                                 ...      ...              ...        ...
# 2017                               26.0   1346.0            112.0       86.0
# 2018                              184.0    973.0            105.0      119.0
# 2019                              -26.0   1779.0            297.0      238.0
# 2020                              108.0   2211.0            101.0       71.0
# 2021                              -32.0    315.0           -133.0      -86.0
#
#       ...     2021/08                                                   \
#       ... Liabilities Owners Equity Cashflow from Operating Activities
# 0     ...         NaN           NaN                                NaN
# 1     ...         NaN           NaN                                NaN
# 2     ...         NaN           NaN                                NaN
# 3     ...         NaN           NaN                                NaN
# 4     ...         NaN           NaN                                NaN
# ...   ...         ...           ...                                ...
# 2017  ...         NaN           NaN                                NaN
# 2018  ...         NaN           NaN                                NaN
# 2019  ...         NaN           NaN                                NaN
# 2020  ...         NaN           NaN                                NaN
# 2021  ...         NaN           NaN                                NaN
#
#      2022/08                                                               \
#        Sales Operating Income Net Income Assets Liabilities Owners Equity
# 0        NaN              NaN        NaN    NaN         NaN           NaN
# 1        NaN              NaN        NaN    NaN         NaN           NaN
# 2        NaN              NaN        NaN    NaN         NaN           NaN
# 3        NaN              NaN        NaN    NaN         NaN           NaN
# 4        NaN              NaN        NaN    NaN         NaN           NaN
# ...      ...              ...        ...    ...         ...           ...
# 2017     NaN              NaN        NaN    NaN         NaN           NaN
# 2018     NaN              NaN        NaN    NaN         NaN           NaN
# 2019     NaN              NaN        NaN    NaN         NaN           NaN
# 2020     NaN              NaN        NaN    NaN         NaN           NaN
# 2021     NaN              NaN        NaN    NaN         NaN           NaN
#
#
#      Cashflow from Operating Activities
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2017                                NaN
# 2018                                NaN
# 2019                                NaN
# 2020                                NaN
# 2021                                NaN
#
# [2022 rows x 168 columns]

# %%
pip install html5lib
# Out:
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in c:\users\jongh\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jongh\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.94-py3-none-any.whl.metadata (466 bytes)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\jongh\anaconda3\lib\site-packages (from finance-datareader) (2.2.2)
# Requirement already satisfied: requests>=2.3.0 in c:\users\jongh\anaconda3\lib\site-packages (from finance-datareader) (2.32.3)
# Requirement already satisfied: requests-file in c:\users\jongh\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in c:\users\jongh\anaconda3\lib\site-packages (from finance-datareader) (5.2.1)
# Requirement already satisfied: tqdm in c:\users\jongh\anaconda3\lib\site-packages (from finance-datareader) (4.66.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jongh\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jongh\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jongh\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jongh\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jongh\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jongh\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jongh\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jongh\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2024.8.30)
# Requirement already satisfied: six in c:\users\jongh\anaconda3\lib\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jongh\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.6)
# Downloading finance_datareader-0.9.94-py3-none-any.whl (89 kB)
# Installing collected packages: finance-datareader
# Successfully installed finance-datareader-0.9.94
# Note: you may need to restart the kernel to use updated packages.

# %%
total_fs.to_excel(r'C:\\Users\\jongh\\Downloads\\Consolidated financial data.xlsx')

# %%
import FinanceDataReader as fdr
import pandas as pd
from tqdm.notebook import tqdm

# %%
krw_list = fdr.StockListing('KRX')
krw_list = krw_list.set_index(krw_list.columns[0])
krw_list
# Out:
#               ISU_CD      Name Market   Dept    Close ChangeCode  Changes  \
# Code
# 005930  KR7005930003      삼성전자  KOSPI           54100          2    -1200
# 000660  KR7000660001    SK하이닉스  KOSPI          194300          2    -9200
# 373220  KR7373220003  LG에너지솔루션  KOSPI          347500          2    -1000
# 207940  KR7207940008  삼성바이오로직스  KOSPI         1012000          1    12000
# 005380  KR7005380001       현대차  KOSPI          220000          2    -6000
# ...              ...       ...    ...    ...      ...        ...      ...
# 140660  KR7140660002       위월드  KONEX  일반기업부      766          2     -132
# 236030  KR7236030003      씨알푸드  KONEX  일반기업부      930          2      -19
# 413300  KR7413300005   티엘엔지니어링  KONEX  일반기업부      899          2       -1
# 288490  KR7288490006     나라소프트  KONEX  일반기업부       61          2       -2
# 308700  KR7308700004       테크엔  KONEX  일반기업부      199          0        0
#
#         ChagesRatio     Open     High      Low    Volume        Amount  \
# Code
# 005930        -2.17    54600    55000    54100  16868600  917178336730
# 000660        -4.52   203000   203000   193900   4767294  939206630700
# 373220        -0.29   346500   350500   345500    165688   57694408000
# 207940         1.20  1006000  1044000  1005000     72362   73835125000
# 005380        -2.65   225500   226000   218500    867629  191585700000
# ...             ...      ...      ...      ...       ...           ...
# 140660       -14.70      830      899      766       521        431219
# 236030        -2.00      930      930      930         2          1860
# 413300        -0.11     1034     1034      765        26         22142
# 288490        -3.17       65       65       61     33880       2190050
# 308700         0.00        0        0        0         0             0
#
#                  Marcap      Stocks MarketId
# Code
# 005930  322965235955000  5969782550      STK
# 000660  141450859519500   728002365      STK
# 373220   81315000000000   234000000      STK
# 207940   72028088000000    71174000      STK
# 005380   46071562020000   209416191      STK
# ...                 ...         ...      ...
# 140660       1905235032     2487252      KNX
# 236030       1890998760     2033332      KNX
# 413300       1215011985     1351515      KNX
# 288490       1065766197    17471577      KNX
# 308700        796000000     4000000      KNX
#
# [2865 rows x 16 columns]

# %%
import time # time used for pausing between requests to avoid overwhelming the server or triggering rate-limiting
import requests # requests used for sending HTTP requests to fetch the financial data from an external source (e.g., a website)

# List to store data frames that will be gathered and processed during the loop
dfs = []  # it initializes an empty list to store the individual data frames for each company code. These data frames will later be combined into a single data frame.

# Loop through each company code in the 'Code' column of the 'code_data_reset' DataFrame
for num, code in enumerate(krw_list['Code']):  # The loop iterates over the code column in the code_data_reset Dataframe. For each company, it fetches and processes the financial data.
    
    try:
        # Print progress to show the current company code being processed      
        print(f"Processing {num + 1}/{len(krw_list['Code'])} - Code: {code}") # It prints the progress of the cript, indicating which company code is being processed and what the progress is.

        # Sleep for 0.1 seconds to avoid making too many requests in a short time (helps prevent throttling or blocking)
        time.sleep(0.1) # This line adds a small delay of 0.1 seconds between requests to avoid making too many requests in a shor time, which could lead to rate-limiting or IP blocking from the server.

        try:
            # Attempt to fetch the financial data for the current company code
            fs_df = make_fs_df(code)  # This part of the codes attempts to fetch the financial data for the current company code using a function make_fs_df().
            

        except requests.exceptions.Timeout:  
        
            # Handle timeout error: if the request times out, wait 60 seconds and then retry fetching the data           
            print(f"Timeout occurred for code {code}. Retrying...")
            
            time.sleep(60)  # Wait for 60 seconds before retrying
            fs_df = make_fs_df(code) # If the request times out, the code waits for 60 seconds and tries again to fetch the data.

        except requests.exceptions.RequestException as e:

            # If there’s a request exception (e.g., network issues, bad response), log the error and move to the next code
            print(f"Request exception occurred for {code}: {e}") # If there's any other issue with the request (e.g., network issue, bad response), the exception is caught, an error message is printed, and the loop moves to the next company code.
            
            continue  # Skip the current iteration and continue with the next company code

        # Check if financial data is returned (fs_df is not None)      
        if fs_df is not None:
            
            # Process the data by changing its structure according to the logic in the 'change_df' function
            fs_df_changed = change_df(code, fs_df)
            
            # Append the processed data frame to the list 'dfs'
            dfs.append(fs_df_changed)

        else:

            # If no financial data is returned for the code, print a message indicating it's skipped           
            print(f"No data returned for {code}, skipping.")

    except (ValueError, KeyError) as e:

        # If there’s an error in processing the data for the code, catch the exception and continue to the next iteration
        print(f"Error processing code {code}: {e}")
        continue # Skip the current code and proceed to the next iteration

# After all iterations, if there are any data frames in the 'dfs' list, concatenate them
if dfs:
    
    # Concatenate all the data frames into one large data frame 'total_fs', row-wise (axis=0)
    total_fs = pd.concat(dfs, axis=0, ignore_index=True)
    print("Successfully consolidated financial data.")

else:
    # If no data frames were added to 'dfs', print a message indicating that no data was available
    print("No financial data available.")

# Display the consolidated financial data in 'total_fs'
total_fs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 8
#       5 dfs = []  # it initializes an empty list to store the individual data frames for each company code. These data frames will later be combined into a single data frame.
#       7 # Loop through each company code in the 'Code' column of the 'code_data_reset' DataFrame
# ----> 8 for num, code in enumerate(krw_list['Code']):  # The loop iterates over the code column in the code_data_reset Dataframe. For each company, it fetches and processes the financial data.
#      10     try:
#      11         # Print progress to show the current company code being processed
#      12         print(f"Processing {num + 1}/{len(krw_list['Code'])} - Code: {code}") # It prints the progress of the cript, indicating which company code is being processed and what the progress is.
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Code'
